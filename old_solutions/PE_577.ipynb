# %%
def triang(n):
    if n <= 0:
        return 0
    return n * (n+1) // 2

# %%
def H(n):
    total = 0
    for k in range(n//3+1):
        total += k * triang(n - 3*k + 1)

    return total

# %%
total = 0
for i in range(3, 12346):
    total += H(i)

print(total)
# Out:
# 265695031399260211
